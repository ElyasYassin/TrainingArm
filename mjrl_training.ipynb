# %% [markdown]
# <h1> MJRL training </h1>
# MJRL Algorithms: TRPO - MBAC - PPO - NPG - DAPG <br>
# source: https://github.com/aravindr93/mjrl/tree/master/mjrl/algos

# %%
import warnings
warnings.filterwarnings('ignore')

import gym
from mjrl.utils.gym_env import GymEnv
from mjrl.policies.gaussian_mlp import MLP, RNN
from mjrl.baselines.mlp_baseline import MLPBaseline
from mjrl.algos.ppo_clip import PPO
from mjrl.algos.npg_cg import NPG
from mjrl.utils.train_agent import train_agent
import myosuite
import torch
# Out:
# MyoSuite:> Registering Myo Envs

# %% [markdown]
# <h2> Setting up GPU Usage

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Create the environment
# Find tasks in: \envs\myo\myobase or \envs\myo\myochallenge
env = gym.make('CenterReachOut-v0')
env.reset()
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# array([-2.2856e-02,  1.1130e-02, -8.2680e-02,  1.0125e-01, -4.9400e-02,
#         1.6578e-01,  1.1868e-01, -1.9320e-01, -1.9648e-01,  3.8760e-02,
#         1.6806e-01,  1.7281e-01, -2.5407e-01, -1.0998e-01,  1.4748e+00,
#         1.2882e+00,  1.0647e-01, -2.7489e-01,  3.3200e-01,  4.1140e-01,
#        -1.7716e-01, -2.6182e-01,  1.8852e-01,  1.7017e-01,  4.4773e-01,
#         2.6707e-01,  2.8278e-01, -1.0472e-02,  1.6854e-02,  7.0198e-03,
#         9.1390e-02, -6.5450e-02,  2.4350e-01,  3.3776e-01,  2.3565e-01,
#        -1.0184e-01,  6.0707e-04,  3.1420e-02, -2.0000e-01,  0.0000e+00,
#        -2.0000e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00, -9.8006e-02, -3.4574e-01,
#         1.0700e+00, -1.4108e-01,  1.0621e-01, -1.7668e-02,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         0.0000e+00,  0.0000e+00])

# %% [markdown]
# <h1> Hyperparameter tuning </h1>
# Still working on it

# %%
import numpy as np
from sklearn.model_selection import ParameterSampler

param_grid = {
    'policy_size': [(256, 256), (128, 128), (64, 64)],
    'rl_step_size': np.logspace(-4, 0, num=10),
    'learnrate': np.logspace(-4, 0, num=10),
    'entcoeff': np.logspace(-4, 0, num=10),
    'batchsize': [16, 32, 64, 128],
    'num_epoch': [5, 10, 20],
    'vf_hidden_size': [(256, 256), (128, 128), (64, 64)],
    'regcoef': np.logspace(-4, 0, num=10),
    'gamma': np.linspace(0.9, 0.999, num=10),
    'gae_lambda': np.linspace(0.9, 1.0, num=10)
}

n_iter_search = 50  

random_search = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=123))

# %%
#Policy hyperparameters
seed = 1  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.00025
entcoeff = 0.1
batchsize = 16
num_epoch = 10

#Value Function hyperparameters
vf_hidden_size = (256, 256) # Value Function Network size
seed = 1  # Random seed used for reproducibility
rl_step_size = 0.1
learnrate = 0.000325
entcoeff = 0.1
batchsize = 32
num_epoch = 10
regcoef = 1e-3

#Training hyperparameters
iterations = 1000
gamma = 0.995
gae_lambda = 0.97


# Wrap the environment
e = GymEnv(env)

# %% [markdown]
# <H1>Set Policies </h1>

# %% [markdown]
# <h2> For CenterReachOut: </h2>
#     - <b> The observation dimension </b> is: the sensory information (Time, joint Positions, Joint Velocities, Object Position, Palm Position etc... ) <br>
#     - <b> The action dimension </b> is the output of the Policy NN and represenents the 63 values of muscle actuator intensities
#
# <h2> Display Activations:</h2>
#     - When the code down below will run, it will automatically generate a tensorboard event that registers the Policy Network.

# %%
# Initialize policy and baseline
policy = RNN(e.spec, rnn_hidden_size=64, mlp_hidden_size=64, seed=seed, init_log_std=0.25, min_log_std=1.0)
baseline = MLPBaseline(e.spec, reg_coef=regcoef, batch_size=batchsize , hidden_sizes=vf_hidden_size, epochs=num_epoch, learn_rate=learnrate)


print(e.observation_dim) #For CenterReachOut-v0: 157 
print(e.action_dim) #For CenterReachOut-v0: 63 
exit
# Initialize NPG/PPO agent
agent = NPG(e, policy, baseline, normalized_step_size=rl_step_size, seed=seed, save_logs=True,ent_coeff=entcoeff ,tensorboard_log="./ppo_objhold_tensorboard/")
# Out:
# 157
# 63

# %%
print("========================================")
print("Starting policy learning")
print("========================================")

# Train the agent
final_score = train_agent(job_name='.',
            agent=agent,
            seed=seed,
            niter=2500,
            gamma=gamma,
            gae_lambda=gae_lambda,
            sample_mode="trajectories",
            policy_dir='iterations1',
            logs_dir='logs1',
            num_cpu = 1,
            num_traj=96,
            num_samples=0,
            save_freq=1,
            evaluation_rollouts=10)

print("========================================")
print("Job Finished.")
print("========================================")
# Out:
# ========================================
# Starting policy learning
# ========================================
# ......................................................................................
# ITERATION : 0
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x000001928973BF20>
# Iter | Stoc Pol | Mean Pol | Best (Stoc)
#
# [ Sat May 17 18:03:28 2025 ]    0 -4919.05 -2151.58 -100000000.00
# ------------------  -------------
# VF_error_after          0.0454706
# VF_error_before         1.00003
# alpha                   0.0314214
# delta                   0.1
# env_samples          9600
# eval_score          -2151.58
# eval_success            0
# kl_dist                22.7815
# num_samples          9600
# rollout_success         0
# running_score       -4919.05
# rwd_dense             -49.1905
# rwd_sparse             -0.460444
# stoc_pol_max        -4395.85
# stoc_pol_mean       -4919.05
# stoc_pol_min        -5059.33
# stoc_pol_std          150.556
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.17776
# time_npg                0.46726
# time_sampling          25.7911
# time_vpg                0.022043
# ------------------  -------------
# ......................................................................................
# ITERATION : 1
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:04:06 2025 ]    1 -4887.68 -4312.12 -4919.05
# ------------------  -------------
# VF_error_after          0.0202617
# VF_error_before         0.0490881
# alpha                   0.0355157
# delta                   0.1
# env_samples         19200
# eval_score          -4312.12
# eval_success            0
# kl_dist                 0.0376106
# num_samples          9600
# rollout_success         0
# running_score       -4915.91
# rwd_dense             -48.8768
# rwd_sparse             -0.460914
# stoc_pol_max        -4147.67
# stoc_pol_mean       -4887.68
# stoc_pol_min        -5060.8
# stoc_pol_std          177.793
# success_percentage      0
# surr_improvement      nan
# time_VF                 5.61153
# time_npg                0.415286
# time_sampling          26.6193
# time_vpg                0.0228
# ------------------  -------------
# ......................................................................................
# ITERATION : 2
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDB30>
# [ Sat May 17 18:04:41 2025 ]    2 -4911.31 -4746.87 -4887.68
# ------------------  -------------
# VF_error_after          0.011896
# VF_error_before         0.0202335
# alpha                   0.0323764
# delta                   0.1
# env_samples         28800
# eval_score          -4746.87
# eval_success            0
# kl_dist                 0.0297931
# num_samples          9600
# rollout_success         0
# running_score       -4915.45
# rwd_dense             -49.113
# rwd_sparse             -0.452123
# stoc_pol_max        -4243.48
# stoc_pol_mean       -4911.31
# stoc_pol_min        -5060.98
# stoc_pol_std          171.718
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.1838
# time_npg                0.489475
# time_sampling          25.7611
# time_vpg                0.0260391
# ------------------  -------------
# ......................................................................................
# ITERATION : 3
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:05:16 2025 ]    3 -4887.92 -3605.28 -4887.68
# ------------------  --------------
# VF_error_after          0.00769339
# VF_error_before         0.0129826
# alpha                   0.0374312
# delta                   0.1
# env_samples         38400
# eval_score          -3605.28
# eval_success            0
# kl_dist                 0.0371536
# num_samples          9600
# rollout_success         0
# running_score       -4912.7
# rwd_dense             -48.8792
# rwd_sparse             -0.467802
# stoc_pol_max        -4394.08
# stoc_pol_mean       -4887.92
# stoc_pol_min        -5056.09
# stoc_pol_std          152.624
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.92542
# time_npg                0.475943
# time_sampling          25.2215
# time_vpg                0.0270562
# ------------------  --------------
# ......................................................................................
# ITERATION : 4
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:05:51 2025 ]    4 -4919.19 -3867.83 -4887.68
# ------------------  --------------
# VF_error_after          0.00362828
# VF_error_before         0.00895466
# alpha                   0.0411778
# delta                   0.1
# env_samples         48000
# eval_score          -3867.83
# eval_success            0
# kl_dist                 0.0394547
# num_samples          9600
# rollout_success         0
# running_score       -4913.35
# rwd_dense             -49.1919
# rwd_sparse             -0.458489
# stoc_pol_max        -4346.14
# stoc_pol_mean       -4919.19
# stoc_pol_min        -5057.03
# stoc_pol_std          149.468
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.27166
# time_npg                0.395785
# time_sampling          25.3073
# time_vpg                0.0253823
# ------------------  --------------
# ......................................................................................
# ITERATION : 5
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:06:28 2025 ]    5 -4884.73 -4172.08 -4887.68
# ------------------  --------------
# VF_error_after          0.00107014
# VF_error_before         0.00320213
# alpha                   0.0369868
# delta                   0.1
# env_samples         57600
# eval_score          -4172.08
# eval_success            0
# kl_dist                 0.0388529
# num_samples          9600
# rollout_success         0
# running_score       -4910.49
# rwd_dense             -48.8473
# rwd_sparse             -0.459837
# stoc_pol_max        -4405.03
# stoc_pol_mean       -4884.73
# stoc_pol_min        -5056.99
# stoc_pol_std          143.876
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.65441
# time_npg                0.614957
# time_sampling          27.0984
# time_vpg                0.0321066
# ------------------  --------------
# ......................................................................................
# ITERATION : 6
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:07:03 2025 ]    6 -4927.66 -4083.14 -4884.73
# ------------------  ---------------
# VF_error_after          0.000376268
# VF_error_before         0.00136255
# alpha                   0.0316391
# delta                   0.1
# env_samples         67200
# eval_score          -4083.14
# eval_success            0
# kl_dist                 0.0343359
# num_samples          9600
# rollout_success         0
# running_score       -4912.2
# rwd_dense             -49.2766
# rwd_sparse             -0.456895
# stoc_pol_max        -4552.58
# stoc_pol_mean       -4927.66
# stoc_pol_min        -5058.98
# stoc_pol_std          132.49
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.17986
# time_npg                0.48285
# time_sampling          25.4853
# time_vpg                0.0287879
# ------------------  ---------------
# ......................................................................................
# ITERATION : 7
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:07:38 2025 ]    7 -4872.86 -3986.36 -4884.73
# ------------------  ---------------
# VF_error_after          0.000297025
# VF_error_before         0.000583666
# alpha                   0.0361244
# delta                   0.1
# env_samples         76800
# eval_score          -3986.36
# eval_success            0
# kl_dist                 0.0439905
# num_samples          9600
# rollout_success         0
# running_score       -4908.27
# rwd_dense             -48.7286
# rwd_sparse             -0.469538
# stoc_pol_max        -4300.93
# stoc_pol_mean       -4872.86
# stoc_pol_min        -5058.95
# stoc_pol_std          171.242
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.0666
# time_npg                0.433443
# time_sampling          25.3237
# time_vpg                0.0270493
# ------------------  ---------------
# ......................................................................................
# ITERATION : 8
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289D76F90>
# [ Sat May 17 18:08:16 2025 ]    8 -4886.12 -4448.24 -4872.86
# ------------------  ---------------
# VF_error_after          0.000143081
# VF_error_before         0.000232586
# alpha                   0.0401289
# delta                   0.1
# env_samples         86400
# eval_score          -4448.24
# eval_success            0
# kl_dist                 0.0454407
# num_samples          9600
# rollout_success         0
# running_score       -4906.06
# rwd_dense             -48.8612
# rwd_sparse             -0.459046
# stoc_pol_max        -4450.37
# stoc_pol_mean       -4886.12
# stoc_pol_min        -5056.63
# stoc_pol_std          140.229
# success_percentage      0
# surr_improvement      nan
# time_VF                 5.58795
# time_npg                0.746456
# time_sampling          26.8869
# time_vpg                0.0340788
# ------------------  ---------------
# ......................................................................................
# ITERATION : 9
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD200>
# [ Sat May 17 18:08:52 2025 ]    9 -4884.30 -4386.47 -4872.86
# ------------------  ---------------
# VF_error_after          0.00018422
# VF_error_before         0.000214197
# alpha                   0.0340258
# delta                   0.1
# env_samples         96000
# eval_score          -4386.47
# eval_success            0
# kl_dist                 0.0451041
# num_samples          9600
# rollout_success         0
# running_score       -4903.88
# rwd_dense             -48.843
# rwd_sparse             -0.457218
# stoc_pol_max        -4390.49
# stoc_pol_mean       -4884.3
# stoc_pol_min        -5057.76
# stoc_pol_std          170.934
# success_percentage      0
# surr_improvement      nan
# time_VF                 4.61983
# time_npg                0.404253
# time_sampling          25.1908
# time_vpg                0.0324881
# ------------------  ---------------
# ......................................................................................
# ITERATION : 10
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDA50>
# [ Sat May 17 18:09:27 2025 ]   10 -4903.17 -4368.88 -4872.86
# ------------------  ----------------
# VF_error_after           0.00013912
# VF_error_before          0.000153697
# alpha                    0.0319804
# delta                    0.1
# env_samples         105600
# eval_score           -4368.88
# eval_success             0
# kl_dist                  0.0450126
# num_samples           9600
# rollout_success          0
# running_score        -4903.81
# rwd_dense              -49.0317
# rwd_sparse              -0.451565
# stoc_pol_max         -4502.57
# stoc_pol_mean        -4903.17
# stoc_pol_min         -5059.51
# stoc_pol_std           156.678
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.2048
# time_npg                 0.584132
# time_sampling           25.207
# time_vpg                 0.0235744
# ------------------  ----------------
# ......................................................................................
# ITERATION : 11
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:10:02 2025 ]   11 -4913.03 -4036.09 -4872.86
# ------------------  ----------------
# VF_error_after           0.000199217
# VF_error_before          0.000286211
# alpha                    0.0390255
# delta                    0.1
# env_samples         115200
# eval_score           -4036.09
# eval_success             0
# kl_dist                  0.0402132
# num_samples           9600
# rollout_success          0
# running_score        -4904.73
# rwd_dense              -49.1303
# rwd_sparse              -0.468024
# stoc_pol_max         -4048.78
# stoc_pol_mean        -4913.03
# stoc_pol_min         -5057.72
# stoc_pol_std           156.65
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.22882
# time_npg                 0.475623
# time_sampling           25.8594
# time_vpg                 0.0295837
# ------------------  ----------------
# ......................................................................................
# ITERATION : 12
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:10:39 2025 ]   12 -4905.04 -4138.49 -4872.86
# ------------------  ----------------
# VF_error_after           0.00019096
# VF_error_before          0.000270746
# alpha                    0.0330771
# delta                    0.1
# env_samples         124800
# eval_score           -4138.49
# eval_success             0
# kl_dist                  0.0452008
# num_samples           9600
# rollout_success          0
# running_score        -4904.76
# rwd_dense              -49.0504
# rwd_sparse              -0.451931
# stoc_pol_max         -4345.58
# stoc_pol_mean        -4905.04
# stoc_pol_min         -5057.38
# stoc_pol_std           165.06
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.83886
# time_npg                 0.382192
# time_sampling           26.3548
# time_vpg                 0.0220449
# ------------------  ----------------
# ......................................................................................
# ITERATION : 13
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDF20>
# [ Sat May 17 18:11:17 2025 ]   13 -4903.08 -4124.73 -4872.86
# ------------------  ----------------
# VF_error_after           0.000138577
# VF_error_before          0.000147394
# alpha                    0.0299924
# delta                    0.1
# env_samples         134400
# eval_score           -4124.73
# eval_success             0
# kl_dist                  0.0431213
# num_samples           9600
# rollout_success          0
# running_score        -4904.59
# rwd_dense              -49.0308
# rwd_sparse              -0.461499
# stoc_pol_max         -4450.88
# stoc_pol_mean        -4903.08
# stoc_pol_min         -5057.66
# stoc_pol_std           148.963
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.151
# time_npg                 0.608872
# time_sampling           27.512
# time_vpg                 0.0267973
# ------------------  ----------------
# ......................................................................................
# ITERATION : 14
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDAC0>
# [ Sat May 17 18:11:56 2025 ]   14 -4882.19 -4539.47 -4872.86
# ------------------  ----------------
# VF_error_after           0.000245656
# VF_error_before          0.0010228
# alpha                    0.0353804
# delta                    0.1
# env_samples         144000
# eval_score           -4539.47
# eval_success             0
# kl_dist                  0.0393036
# num_samples           9600
# rollout_success          0
# running_score        -4902.35
# rwd_dense              -48.8219
# rwd_sparse              -0.462126
# stoc_pol_max         -4196.52
# stoc_pol_mean        -4882.19
# stoc_pol_min         -5062.45
# stoc_pol_std           169.104
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.25705
# time_npg                 0.490325
# time_sampling           29.1283
# time_vpg                 0.0264504
# ------------------  ----------------
# ......................................................................................
# ITERATION : 15
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:12:34 2025 ]   15 -4893.49 -4278.61 -4872.86
# ------------------  ----------------
# VF_error_after           0.000215597
# VF_error_before          0.000239935
# alpha                    0.0332778
# delta                    0.1
# env_samples         153600
# eval_score           -4278.61
# eval_success             0
# kl_dist                  0.0462931
# num_samples           9600
# rollout_success          0
# running_score        -4901.47
# rwd_dense              -48.9349
# rwd_sparse              -0.455336
# stoc_pol_max         -4246.68
# stoc_pol_mean        -4893.49
# stoc_pol_min         -5058
# stoc_pol_std           185.719
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.63908
# time_npg                 0.957088
# time_sampling           26.0139
# time_vpg                 0.092696
# ------------------  ----------------
# ......................................................................................
# ITERATION : 16
# Performing evaluation rollouts ........
# Simulation couldn't be stepped as intended. Issuing a reset
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDCF0>
# [ Sat May 17 18:13:09 2025 ]   16 -4887.62 -4438.78 -4872.86
# ------------------  ----------------
# VF_error_after           0.000176629
# VF_error_before          0.000222294
# alpha                    0.0418148
# delta                    0.1
# env_samples         163200
# eval_score           -4438.78
# eval_success             0
# kl_dist                  0.0455352
# num_samples           9600
# rollout_success          0
# running_score        -4900.08
# rwd_dense              -48.8762
# rwd_sparse              -0.454808
# stoc_pol_max         -4244.35
# stoc_pol_mean        -4887.62
# stoc_pol_min         -5057.4
# stoc_pol_std           176.344
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.25055
# time_npg                 0.416287
# time_sampling           26.5113
# time_vpg                 0.019037
# ------------------  ----------------
# ......................................................................................
# ITERATION : 17
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDAC0>
# [ Sat May 17 18:13:42 2025 ]   17 -4908.26 -4482.43 -4872.86
# ------------------  ----------------
# VF_error_after           0.00012608
# VF_error_before          0.000148909
# alpha                    0.0335673
# delta                    0.1
# env_samples         172800
# eval_score           -4482.43
# eval_success             0
# kl_dist                  0.0427204
# num_samples           9600
# rollout_success          0
# running_score        -4900.9
# rwd_dense              -49.0826
# rwd_sparse              -0.450848
# stoc_pol_max         -4453.98
# stoc_pol_mean        -4908.26
# stoc_pol_min         -5057
# stoc_pol_std           148.419
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.29793
# time_npg                 0.37063
# time_sampling           23.5274
# time_vpg                 0.0200443
# ------------------  ----------------
# ......................................................................................
# ITERATION : 18
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:14:15 2025 ]   18 -4854.26 -4456.38 -4872.86
# ------------------  ----------------
# VF_error_after           0.000196389
# VF_error_before          0.000239242
# alpha                    0.0361927
# delta                    0.1
# env_samples         182400
# eval_score           -4456.38
# eval_success             0
# kl_dist                  0.0460094
# num_samples           9600
# rollout_success          0
# running_score        -4896.24
# rwd_dense              -48.5426
# rwd_sparse              -0.45221
# stoc_pol_max         -4289.9
# stoc_pol_mean        -4854.26
# stoc_pol_min         -5056.35
# stoc_pol_std           186.521
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.40973
# time_npg                 0.394853
# time_sampling           23.6365
# time_vpg                 0.0210369
# ------------------  ----------------
# ......................................................................................
# ITERATION : 19
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD200>
# [ Sat May 17 18:14:48 2025 ]   19 -4883.02 -4477.37 -4854.26
# ------------------  ----------------
# VF_error_after           0.00022496
# VF_error_before          0.000520942
# alpha                    0.0344849
# delta                    0.1
# env_samples         192000
# eval_score           -4477.37
# eval_success             0
# kl_dist                  0.0422059
# num_samples           9600
# rollout_success          0
# running_score        -4894.91
# rwd_dense              -48.8302
# rwd_sparse              -0.464884
# stoc_pol_max         -4397.52
# stoc_pol_mean        -4883.02
# stoc_pol_min         -5056.59
# stoc_pol_std           186.116
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.33144
# time_npg                 0.379255
# time_sampling           23.7588
# time_vpg                 0.0190485
# ------------------  ----------------
# ......................................................................................
# ITERATION : 20
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDAC0>
# [ Sat May 17 18:15:20 2025 ]   20 -4904.26 -4515.96 -4854.26
# ------------------  ----------------
# VF_error_after           0.000122214
# VF_error_before          0.000147476
# alpha                    0.0389467
# delta                    0.1
# env_samples         201600
# eval_score           -4515.96
# eval_success             0
# kl_dist                  0.0474459
# num_samples           9600
# rollout_success          0
# running_score        -4895.85
# rwd_dense              -49.0426
# rwd_sparse              -0.458598
# stoc_pol_max         -4386.02
# stoc_pol_mean        -4904.26
# stoc_pol_min         -5059.75
# stoc_pol_std           153.556
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.41072
# time_npg                 0.451224
# time_sampling           23.1546
# time_vpg                 0.0235856
# ------------------  ----------------
# ......................................................................................
# ITERATION : 21
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:15:52 2025 ]   21 -4861.35 -4517.82 -4854.26
# ------------------  ----------------
# VF_error_after           0.000262461
# VF_error_before          0.00150455
# alpha                    0.0327256
# delta                    0.1
# env_samples         211200
# eval_score           -4517.82
# eval_success             0
# kl_dist                  0.0402821
# num_samples           9600
# rollout_success          0
# running_score        -4892.4
# rwd_dense              -48.6134
# rwd_sparse              -0.475618
# stoc_pol_max         -4065.78
# stoc_pol_mean        -4861.35
# stoc_pol_min         -5055.38
# stoc_pol_std           196.944
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.93703
# time_npg                 0.437702
# time_sampling           23.2357
# time_vpg                 0.0212235
# ------------------  ----------------
# ......................................................................................
# ITERATION : 22
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDCF0>
# [ Sat May 17 18:16:26 2025 ]   22 -4903.83 -4587.39 -4854.26
# ------------------  ----------------
# VF_error_after           9.96748e-05
# VF_error_before          0.000131307
# alpha                    0.0362703
# delta                    0.1
# env_samples         220800
# eval_score           -4587.39
# eval_success             0
# kl_dist                  0.0478317
# num_samples           9600
# rollout_success          0
# running_score        -4893.54
# rwd_dense              -49.0383
# rwd_sparse              -0.448567
# stoc_pol_max         -4496.5
# stoc_pol_mean        -4903.83
# stoc_pol_min         -5058.21
# stoc_pol_std           147.39
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.1921
# time_npg                 0.524293
# time_sampling           24.0489
# time_vpg                 0.0207722
# ------------------  ----------------
# ......................................................................................
# ITERATION : 23
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD200>
# [ Sat May 17 18:16:59 2025 ]   23 -4856.10 -4633.74 -4854.26
# ------------------  ----------------
# VF_error_after           0.000229104
# VF_error_before          0.000300163
# alpha                    0.0345597
# delta                    0.1
# env_samples         230400
# eval_score           -4633.74
# eval_success             0
# kl_dist                  0.0475885
# num_samples           9600
# rollout_success          0
# running_score        -4889.8
# rwd_dense              -48.561
# rwd_sparse              -0.448924
# stoc_pol_max         -4240
# stoc_pol_mean        -4856.1
# stoc_pol_min         -5059.78
# stoc_pol_std           207.067
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.64454
# time_npg                 0.49697
# time_sampling           23.8188
# time_vpg                 0.0285778
# ------------------  ----------------
# ......................................................................................
# ITERATION : 24
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:17:32 2025 ]   24 -4899.07 -4616.91 -4854.26
# ------------------  ----------------
# VF_error_after           0.000136937
# VF_error_before          0.000175676
# alpha                    0.0317072
# delta                    0.1
# env_samples         240000
# eval_score           -4616.91
# eval_success             0
# kl_dist                  0.047148
# num_samples           9600
# rollout_success          0
# running_score        -4890.73
# rwd_dense              -48.9907
# rwd_sparse              -0.458287
# stoc_pol_max         -4445.8
# stoc_pol_mean        -4899.07
# stoc_pol_min         -5061.06
# stoc_pol_std           150.603
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.97962
# time_npg                 0.422694
# time_sampling           23.5789
# time_vpg                 0.026799
# ------------------  ----------------
# ......................................................................................
# ITERATION : 25
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDAC0>
# [ Sat May 17 18:18:06 2025 ]   25 -4932.60 -4579.95 -4854.26
# ------------------  ----------------
# VF_error_after           7.78204e-05
# VF_error_before          0.000109982
# alpha                    0.0335143
# delta                    0.1
# env_samples         249600
# eval_score           -4579.95
# eval_success             0
# kl_dist                  0.0470094
# num_samples           9600
# rollout_success          0
# running_score        -4894.91
# rwd_dense              -49.326
# rwd_sparse              -0.449398
# stoc_pol_max         -4451.8
# stoc_pol_mean        -4932.6
# stoc_pol_min         -5056.24
# stoc_pol_std           136.437
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.57462
# time_npg                 0.42143
# time_sampling           25.0435
# time_vpg                 0.0238793
# ------------------  ----------------
# ......................................................................................
# ITERATION : 26
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD200>
# [ Sat May 17 18:18:37 2025 ]   26 -4886.49 -4647.49 -4854.26
# ------------------  ----------------
# VF_error_after           0.00014533
# VF_error_before          0.000171439
# alpha                    0.0372894
# delta                    0.1
# env_samples         259200
# eval_score           -4647.49
# eval_success             0
# kl_dist                  0.0486027
# num_samples           9600
# rollout_success          0
# running_score        -4894.07
# rwd_dense              -48.8649
# rwd_sparse              -0.453047
# stoc_pol_max         -4382.71
# stoc_pol_mean        -4886.49
# stoc_pol_min         -5055.53
# stoc_pol_std           169.586
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.28877
# time_npg                 0.418856
# time_sampling           22.6537
# time_vpg                 0.0230303
# ------------------  ----------------
# ......................................................................................
# ITERATION : 27
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:19:09 2025 ]   27 -4870.31 -4603.22 -4854.26
# ------------------  ----------------
# VF_error_after           0.000232065
# VF_error_before          0.00026159
# alpha                    0.0345799
# delta                    0.1
# env_samples         268800
# eval_score           -4603.22
# eval_success             0
# kl_dist                  0.0483409
# num_samples           9600
# rollout_success          0
# running_score        -4891.69
# rwd_dense              -48.7031
# rwd_sparse              -0.451124
# stoc_pol_max         -4000.93
# stoc_pol_mean        -4870.31
# stoc_pol_min         -5059.77
# stoc_pol_std           184.943
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.43119
# time_npg                 0.468369
# time_sampling           22.9849
# time_vpg                 0.0230854
# ------------------  ----------------
# ......................................................................................
# ITERATION : 28
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDB30>
# [ Sat May 17 18:19:42 2025 ]   28 -4874.32 -4751.75 -4854.26
# ------------------  ----------------
# VF_error_after           0.000220139
# VF_error_before          0.00059514
# alpha                    0.0374774
# delta                    0.1
# env_samples         278400
# eval_score           -4751.75
# eval_success             0
# kl_dist                  0.0425534
# num_samples           9600
# rollout_success          0
# running_score        -4889.96
# rwd_dense              -48.7432
# rwd_sparse              -0.460184
# stoc_pol_max         -4331.73
# stoc_pol_mean        -4874.32
# stoc_pol_min         -5055.63
# stoc_pol_std           193.591
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.75398
# time_npg                 0.405772
# time_sampling           23.9022
# time_vpg                 0.0225649
# ------------------  ----------------
# ......................................................................................
# ITERATION : 29
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC10>
# [ Sat May 17 18:20:16 2025 ]   29 -4882.04 -4738.05 -4854.26
# ------------------  ----------------
# VF_error_after           0.000193317
# VF_error_before          0.000240955
# alpha                    0.0327694
# delta                    0.1
# env_samples         288000
# eval_score           -4738.05
# eval_success             0
# kl_dist                  0.0432282
# num_samples           9600
# rollout_success          0
# running_score        -4889.17
# rwd_dense              -48.8204
# rwd_sparse              -0.467192
# stoc_pol_max         -4389.98
# stoc_pol_mean        -4882.04
# stoc_pol_min         -5056.77
# stoc_pol_std           172.597
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.13868
# time_npg                 0.424214
# time_sampling           25.6488
# time_vpg                 0.0270631
# ------------------  ----------------
# ......................................................................................
# ITERATION : 30
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:20:49 2025 ]   30 -4862.38 -4730.22 -4854.26
# ------------------  ----------------
# VF_error_after           0.000167618
# VF_error_before          0.000210288
# alpha                    0.0353484
# delta                    0.1
# env_samples         297600
# eval_score           -4730.22
# eval_success             0
# kl_dist                  0.046992
# num_samples           9600
# rollout_success          0
# running_score        -4886.49
# rwd_dense              -48.6238
# rwd_sparse              -0.456018
# stoc_pol_max         -4352.72
# stoc_pol_mean        -4862.38
# stoc_pol_min         -5057.9
# stoc_pol_std           176.922
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.64906
# time_npg                 0.39066
# time_sampling           23.9698
# time_vpg                 0.0210502
# ------------------  ----------------
# ......................................................................................
# ITERATION : 31
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:21:24 2025 ]   31 -4817.08 -4737.50 -4854.26
# ------------------  ---------------
# VF_error_after           0.00195668
# VF_error_before          0.00214828
# alpha                    0.0345734
# delta                    0.1
# env_samples         307108
# eval_score           -4737.5
# eval_success             0
# kl_dist                  0.0481887
# num_samples           9508
# rollout_success          0
# running_score        -4879.55
# rwd_dense              -48.1708
# rwd_sparse              -0.442575
# stoc_pol_max            26.7219
# stoc_pol_mean        -4817.08
# stoc_pol_min         -5059.97
# stoc_pol_std           531.756
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.58149
# time_npg                 0.48703
# time_sampling           25.6207
# time_vpg                 0.0292869
# ------------------  ---------------
# ......................................................................................
# ITERATION : 32
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD6D0>
# [ Sat May 17 18:21:57 2025 ]   32 -4868.91 -4742.74 -4817.08
# ------------------  ----------------
# VF_error_after           0.000211116
# VF_error_before          0.000410055
# alpha                    0.037699
# delta                    0.1
# env_samples         316708
# eval_score           -4742.74
# eval_success             0
# kl_dist                  0.0446
# num_samples           9600
# rollout_success          0
# running_score        -4878.48
# rwd_dense              -48.6891
# rwd_sparse              -0.462098
# stoc_pol_max         -4098.8
# stoc_pol_mean        -4868.91
# stoc_pol_min         -5056.95
# stoc_pol_std           204.198
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.50268
# time_npg                 0.452784
# time_sampling           23.9742
# time_vpg                 0.0250387
# ------------------  ----------------
# ......................................................................................
# ITERATION : 33
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:22:29 2025 ]   33 -4879.78 -4730.66 -4817.08
# ------------------  ----------------
# VF_error_after           0.000132734
# VF_error_before          0.00016415
# alpha                    0.0335685
# delta                    0.1
# env_samples         326308
# eval_score           -4730.66
# eval_success             0
# kl_dist                  0.0450789
# num_samples           9600
# rollout_success          0
# running_score        -4878.61
# rwd_dense              -48.7978
# rwd_sparse              -0.446858
# stoc_pol_max         -4445.47
# stoc_pol_mean        -4879.78
# stoc_pol_min         -5058.78
# stoc_pol_std           172.686
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.07366
# time_npg                 0.428388
# time_sampling           24.0008
# time_vpg                 0.0200369
# ------------------  ----------------
# ......................................................................................
# ITERATION : 34
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:23:02 2025 ]   34 -4862.39 -4716.98 -4817.08
# ------------------  ----------------
# VF_error_after           0.000176938
# VF_error_before          0.000230961
# alpha                    0.0414653
# delta                    0.1
# env_samples         335908
# eval_score           -4716.98
# eval_success             0
# kl_dist                  0.047263
# num_samples           9600
# rollout_success          0
# running_score        -4876.99
# rwd_dense              -48.6239
# rwd_sparse              -0.457339
# stoc_pol_max         -4353.18
# stoc_pol_mean        -4862.39
# stoc_pol_min         -5057.15
# stoc_pol_std           174.338
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.65847
# time_npg                 0.421294
# time_sampling           25.1734
# time_vpg                 0.0247984
# ------------------  ----------------
# ......................................................................................
# ITERATION : 35
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDB30>
# [ Sat May 17 18:23:36 2025 ]   35 -4822.18 -4721.87 -4817.08
# ------------------  ----------------
# VF_error_after           0.000216511
# VF_error_before          0.000277249
# alpha                    0.0371918
# delta                    0.1
# env_samples         345508
# eval_score           -4721.87
# eval_success             0
# kl_dist                  0.0475429
# num_samples           9600
# rollout_success          0
# running_score        -4871.51
# rwd_dense              -48.2218
# rwd_sparse              -0.448914
# stoc_pol_max         -4361.12
# stoc_pol_mean        -4822.18
# stoc_pol_min         -5053.73
# stoc_pol_std           199.842
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.51924
# time_npg                 0.454799
# time_sampling           24.0453
# time_vpg                 0.0230687
# ------------------  ----------------
# ......................................................................................
# ITERATION : 36
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:24:09 2025 ]   36 -4874.58 -4743.31 -4817.08
# ------------------  ----------------
# VF_error_after           0.000145581
# VF_error_before          0.000182502
# alpha                    0.0330993
# delta                    0.1
# env_samples         355108
# eval_score           -4743.31
# eval_success             0
# kl_dist                  0.0409671
# num_samples           9600
# rollout_success          0
# running_score        -4871.82
# rwd_dense              -48.7457
# rwd_sparse              -0.445362
# stoc_pol_max         -4277.01
# stoc_pol_mean        -4874.58
# stoc_pol_min         -5055.76
# stoc_pol_std           174.615
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.30103
# time_npg                 0.514798
# time_sampling           24.6034
# time_vpg                 0.0285773
# ------------------  ----------------
# ......................................................................................
# ITERATION : 37
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD660>
# [ Sat May 17 18:24:45 2025 ]   37 -4806.48 -4768.77 -4817.08
# ------------------  ----------------
# VF_error_after           0.00026534
# VF_error_before          0.000319183
# alpha                    0.0320357
# delta                    0.1
# env_samples         364708
# eval_score           -4768.77
# eval_success             0
# kl_dist                  0.0436926
# num_samples           9600
# rollout_success          0
# running_score        -4865.28
# rwd_dense              -48.0648
# rwd_sparse              -0.451109
# stoc_pol_max         -4252.24
# stoc_pol_mean        -4806.48
# stoc_pol_min         -5057.83
# stoc_pol_std           210.686
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.36852
# time_npg                 0.374387
# time_sampling           26.6497
# time_vpg                 0.0220456
# ------------------  ----------------
# ......................................................................................
# ITERATION : 38
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDBA0>
# [ Sat May 17 18:25:20 2025 ]   38 -4838.88 -4751.41 -4806.48
# ------------------  ----------------
# VF_error_after           0.000350907
# VF_error_before          0.000361451
# alpha                    0.0398694
# delta                    0.1
# env_samples         374308
# eval_score           -4751.41
# eval_success             0
# kl_dist                  0.0479285
# num_samples           9600
# rollout_success          0
# running_score        -4862.64
# rwd_dense              -48.3888
# rwd_sparse              -0.447897
# stoc_pol_max         -4194.58
# stoc_pol_mean        -4838.88
# stoc_pol_min         -5059.07
# stoc_pol_std           211.417
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.21048
# time_npg                 0.461833
# time_sampling           26.1955
# time_vpg                 0.023041
# ------------------  ----------------
# ......................................................................................
# ITERATION : 39
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:25:53 2025 ]   39 -4842.95 -4762.29 -4806.48
# ------------------  ----------------
# VF_error_after           0.000228144
# VF_error_before          0.000328608
# alpha                    0.0333075
# delta                    0.1
# env_samples         383908
# eval_score           -4762.29
# eval_success             0
# kl_dist                  0.0491797
# num_samples           9600
# rollout_success          0
# running_score        -4860.67
# rwd_dense              -48.4295
# rwd_sparse              -0.456916
# stoc_pol_max         -4019.45
# stoc_pol_mean        -4842.95
# stoc_pol_min         -5055.43
# stoc_pol_std           206.966
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.61358
# time_npg                 0.365186
# time_sampling           25.4809
# time_vpg                 0.0200374
# ------------------  ----------------
# ......................................................................................
# ITERATION : 40
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:26:21 2025 ]   40 -4833.05 -4787.49 -4806.48
# ------------------  ----------------
# VF_error_after           0.000260617
# VF_error_before          0.000334475
# alpha                    0.0354125
# delta                    0.1
# env_samples         393508
# eval_score           -4787.49
# eval_success             0
# kl_dist                  0.0467566
# num_samples           9600
# rollout_success          0
# running_score        -4857.91
# rwd_dense              -48.3305
# rwd_sparse              -0.445589
# stoc_pol_max         -4147.11
# stoc_pol_mean        -4833.05
# stoc_pol_min         -5058.33
# stoc_pol_std           209.311
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.30208
# time_npg                 0.346593
# time_sampling           21.1812
# time_vpg                 0.0195401
# ------------------  ----------------
# ......................................................................................
# ITERATION : 41
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:26:50 2025 ]   41 -4838.60 -4749.99 -4806.48
# ------------------  ----------------
# VF_error_after           0.000225059
# VF_error_before          0.000247001
# alpha                    0.0343026
# delta                    0.1
# env_samples         403108
# eval_score           -4749.99
# eval_success             0
# kl_dist                  0.0470296
# num_samples           9600
# rollout_success          0
# running_score        -4855.98
# rwd_dense              -48.386
# rwd_sparse              -0.453764
# stoc_pol_max         -4296.63
# stoc_pol_mean        -4838.6
# stoc_pol_min         -5060.05
# stoc_pol_std           194.424
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.35883
# time_npg                 0.343317
# time_sampling           21.2104
# time_vpg                 0.0200768
# ------------------  ----------------
# ......................................................................................
# ITERATION : 42
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:27:18 2025 ]   42 -4857.07 -4751.48 -4806.48
# ------------------  ----------------
# VF_error_after           0.000157121
# VF_error_before          0.000210084
# alpha                    0.0351857
# delta                    0.1
# env_samples         412708
# eval_score           -4751.48
# eval_success             0
# kl_dist                  0.0494395
# num_samples           9600
# rollout_success          0
# running_score        -4856.09
# rwd_dense              -48.5707
# rwd_sparse              -0.456298
# stoc_pol_max         -4350.38
# stoc_pol_mean        -4857.07
# stoc_pol_min         -5057.39
# stoc_pol_std           188.218
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.29547
# time_npg                 0.346051
# time_sampling           21.4477
# time_vpg                 0.0180402
# ------------------  ----------------
# ......................................................................................
# ITERATION : 43
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:27:47 2025 ]   43 -4839.46 -4760.87 -4806.48
# ------------------  ----------------
# VF_error_after           0.000185106
# VF_error_before          0.000272584
# alpha                    0.0341068
# delta                    0.1
# env_samples         422308
# eval_score           -4760.87
# eval_success             0
# kl_dist                  0.0453176
# num_samples           9600
# rollout_success          0
# running_score        -4854.43
# rwd_dense              -48.3946
# rwd_sparse              -0.460541
# stoc_pol_max         -4221.98
# stoc_pol_mean        -4839.46
# stoc_pol_min         -5060.61
# stoc_pol_std           196.51
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.3044
# time_npg                 0.343501
# time_sampling           21.6651
# time_vpg                 0.0195374
# ------------------  ----------------
# ......................................................................................
# ITERATION : 44
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:28:16 2025 ]   44 -4807.77 -4749.19 -4806.48
# ------------------  ----------------
# VF_error_after           0.00029777
# VF_error_before          0.000363431
# alpha                    0.0341284
# delta                    0.1
# env_samples         431908
# eval_score           -4749.19
# eval_success             0
# kl_dist                  0.0465365
# num_samples           9600
# rollout_success          0
# running_score        -4849.76
# rwd_dense              -48.0777
# rwd_sparse              -0.449651
# stoc_pol_max         -4136.23
# stoc_pol_mean        -4807.77
# stoc_pol_min         -5057.94
# stoc_pol_std           226.628
# success_percentage       0
# surr_improvement       nan
# time_VF                  3.37049
# time_npg                 0.350345
# ...
# num_samples           9600
# rollout_success          0
# running_score        -4757.22
# rwd_dense              -47.358
# rwd_sparse              -0.48025
# stoc_pol_max         -3726.57
# stoc_pol_mean        -4735.8
# stoc_pol_min         -5059.98
# stoc_pol_std           325.141
# success_percentage       0
# surr_improvement       nan
# time_VF                  6.16056
# time_npg                 0.530982
# time_sampling           26.9202
# time_vpg                 0.0200467
# ------------------  ----------------
# ......................................................................................
# ITERATION : 86
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:49:14 2025 ]   86 -4750.23 -4218.68 -4667.63
# ------------------  ----------------
# VF_error_after           0.000424125
# VF_error_before          0.000540393
# alpha                    0.0343595
# delta                    0.1
# env_samples         835012
# eval_score           -4218.68
# eval_success             0
# kl_dist                  0.0493125
# num_samples           9600
# rollout_success          0
# running_score        -4756.52
# rwd_dense              -47.5023
# rwd_sparse              -0.45927
# stoc_pol_max         -3791.35
# stoc_pol_mean        -4750.23
# stoc_pol_min         -5058.83
# stoc_pol_std           305.681
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.87442
# time_npg                 0.562922
# time_sampling           31.0573
# time_vpg                 0.0340822
# ------------------  ----------------
# ......................................................................................
# ITERATION : 87
# Performing evaluation rollouts ........
# Simulation couldn't be stepped as intended. Issuing a reset
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC10>
# [ Sat May 17 18:49:56 2025 ]   87 -4695.46 -4204.85 -4667.63
# ------------------  ----------------
# VF_error_after           0.000592194
# VF_error_before          0.000742405
# alpha                    0.0335076
# delta                    0.1
# env_samples         844612
# eval_score           -4204.85
# eval_success             0
# kl_dist                  0.037795
# num_samples           9600
# rollout_success          0
# running_score        -4750.42
# rwd_dense              -46.9545
# rwd_sparse              -0.463191
# stoc_pol_max         -3869.34
# stoc_pol_mean        -4695.46
# stoc_pol_min         -5054.17
# stoc_pol_std           354.079
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.78097
# time_npg                 0.581861
# time_sampling           30.3399
# time_vpg                 0.0322242
# ------------------  ----------------
# ......................................................................................
# ITERATION : 88
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:50:39 2025 ]   88 -4766.05 -4311.90 -4667.63
# ------------------  ----------------
# VF_error_after           0.000285396
# VF_error_before          0.000500989
# alpha                    0.0347738
# delta                    0.1
# env_samples         854212
# eval_score           -4311.9
# eval_success             0
# kl_dist                  0.0490763
# num_samples           9600
# rollout_success          0
# running_score        -4751.98
# rwd_dense              -47.6605
# rwd_sparse              -0.469733
# stoc_pol_max         -4179.18
# stoc_pol_mean        -4766.05
# stoc_pol_min         -5055.81
# stoc_pol_std           283.756
# success_percentage       0
# surr_improvement       nan
# time_VF                  8.18773
# time_npg                 0.509846
# time_sampling           30.3325
# time_vpg                 0.0290608
# ------------------  ----------------
# ......................................................................................
# ITERATION : 89
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDCF0>
# [ Sat May 17 18:51:13 2025 ]   89 -4643.44 -4285.99 -4667.63
# ------------------  ----------------
# VF_error_after           0.000555985
# VF_error_before          0.000969764
# alpha                    0.0330904
# delta                    0.1
# env_samples         863812
# eval_score           -4285.99
# eval_success             0
# kl_dist                  0.0481659
# num_samples           9600
# rollout_success          0
# running_score        -4741.13
# rwd_dense              -46.4344
# rwd_sparse              -0.463271
# stoc_pol_max         -3470.75
# stoc_pol_mean        -4643.44
# stoc_pol_min         -5059.78
# stoc_pol_std           372.534
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.03781
# time_npg                 0.443848
# time_sampling           25.2527
# time_vpg                 0.0250967
# ------------------  ----------------
# ......................................................................................
# ITERATION : 90
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:51:46 2025 ]   90 -4688.63 -4056.47 -4643.44
# ------------------  ----------------
# VF_error_after           0.000630007
# VF_error_before          0.000902154
# alpha                    0.0380968
# delta                    0.1
# env_samples         873412
# eval_score           -4056.47
# eval_success             0
# kl_dist                  0.0452633
# num_samples           9600
# rollout_success          0
# running_score        -4735.88
# rwd_dense              -46.8863
# rwd_sparse              -0.485999
# stoc_pol_max         -3479.5
# stoc_pol_mean        -4688.63
# stoc_pol_min         -5056.19
# stoc_pol_std           346.381
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.20558
# time_npg                 0.431622
# time_sampling           24.4137
# time_vpg                 0.024545
# ------------------  ----------------
# ......................................................................................
# ITERATION : 91
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCD890>
# [ Sat May 17 18:52:19 2025 ]   91 -4685.37 -4042.64 -4643.44
# ------------------  ----------------
# VF_error_after           0.000466206
# VF_error_before          0.000608736
# alpha                    0.0348892
# delta                    0.1
# env_samples         883012
# eval_score           -4042.64
# eval_success             0
# kl_dist                  0.0463338
# num_samples           9600
# rollout_success          0
# running_score        -4730.83
# rwd_dense              -46.8537
# rwd_sparse              -0.451748
# stoc_pol_max         -3764.85
# stoc_pol_mean        -4685.37
# stoc_pol_min         -5057.59
# stoc_pol_std           356.971
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.01257
# time_npg                 0.409348
# time_sampling           24.5343
# time_vpg                 0.0230415
# ------------------  ----------------
# ......................................................................................
# ITERATION : 92
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDBA0>
# [ Sat May 17 18:52:53 2025 ]   92 -4704.90 -4104.29 -4643.44
# ------------------  ---------------
# VF_error_after           0.00136828
# VF_error_before          0.00161493
# alpha                    0.0373737
# delta                    0.1
# env_samples         892518
# eval_score           -4104.29
# eval_success             0
# kl_dist                  0.0487614
# num_samples           9506
# rollout_success          0
# running_score        -4728.23
# rwd_dense              -47.049
# rwd_sparse              -0.462625
# stoc_pol_max            10.773
# stoc_pol_mean        -4704.9
# stoc_pol_min         -5058.6
# stoc_pol_std           566.051
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.3544
# time_npg                 0.454875
# time_sampling           24.9895
# time_vpg                 0.0238616
# ------------------  ---------------
# ......................................................................................
# ITERATION : 93
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC80>
# [ Sat May 17 18:53:30 2025 ]   93 -4717.26 -4041.67 -4643.44
# ------------------  ----------------
# VF_error_after           0.000611117
# VF_error_before          0.000830902
# alpha                    0.0341173
# delta                    0.1
# env_samples         902118
# eval_score           -4041.67
# eval_success             0
# kl_dist                  0.045845
# num_samples           9600
# rollout_success          0
# running_score        -4727.14
# rwd_dense              -47.1726
# rwd_sparse              -0.451679
# stoc_pol_max         -3711.8
# stoc_pol_mean        -4717.26
# stoc_pol_min         -5058.39
# stoc_pol_std           349.924
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.49023
# time_npg                 0.469269
# time_sampling           27.1962
# time_vpg                 0.0270431
# ------------------  ----------------
# ......................................................................................
# ITERATION : 94
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDD60>
# [ Sat May 17 18:54:04 2025 ]   94 -4704.58 -4316.82 -4643.44
# ------------------  ---------------
# VF_error_after           0.00302792
# VF_error_before          0.00366768
# alpha                    0.0358949
# delta                    0.1
# env_samples         911634
# eval_score           -4316.82
# eval_success             0
# kl_dist                  0.0477328
# num_samples           9516
# rollout_success          0
# running_score        -4724.88
# rwd_dense              -47.0458
# rwd_sparse              -0.472734
# stoc_pol_max            37.0972
# stoc_pol_mean        -4704.58
# stoc_pol_min         -5058.34
# stoc_pol_std           580.538
# success_percentage       0
# surr_improvement       nan
# time_VF                  4.41649
# time_npg                 0.443038
# time_sampling           25.4969
# time_vpg                 0.0218401
# ------------------  ---------------
# ......................................................................................
# ITERATION : 95
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC10>
# [ Sat May 17 18:54:52 2025 ]   95 -4537.26 -4254.75 -4643.44
# ------------------  ---------------
# VF_error_after           0.00280971
# VF_error_before          0.00338213
# alpha                    0.0308978
# delta                    0.1
# env_samples         921047
# eval_score           -4254.75
# eval_success             0
# kl_dist                  0.0481749
# num_samples           9413
# rollout_success          0
# running_score        -4706.12
# rwd_dense              -45.3726
# rwd_sparse              -0.440285
# stoc_pol_max            23.0651
# stoc_pol_mean        -4537.26
# stoc_pol_min         -5056.1
# stoc_pol_std           772.074
# success_percentage       0
# surr_improvement       nan
# time_VF                 12.2009
# time_npg                 1.68217
# time_sampling           28.5642
# time_vpg                 0.0315704
# ------------------  ---------------
# ......................................................................................
# ITERATION : 96
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDCF0>
# [ Sat May 17 18:55:38 2025 ]   96 -4654.55 -3648.89 -4537.26
# ------------------  ----------------
# VF_error_after           0.000529045
# VF_error_before          0.000840544
# alpha                    0.0365617
# delta                    0.1
# env_samples         930647
# eval_score           -3648.89
# eval_success             0
# kl_dist                  0.0500173
# num_samples           9600
# rollout_success          0
# running_score        -4700.96
# rwd_dense              -46.5455
# rwd_sparse              -0.463154
# stoc_pol_max         -3707.91
# stoc_pol_mean        -4654.55
# stoc_pol_min         -5055.93
# stoc_pol_std           367.992
# success_percentage       0
# surr_improvement         6.86181e+25
# time_VF                  6.86315
# time_npg                 0.559921
# time_sampling           32.6886
# time_vpg                 0.033082
# ------------------  ----------------
# ......................................................................................
# ITERATION : 97
# Simulation couldn't be stepped as intended. Issuing a reset
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC10>
# [ Sat May 17 18:56:27 2025 ]   97 -4674.50 -4001.61 -4537.26
# ------------------  ----------------
# VF_error_after           0.000634992
# VF_error_before          0.00081707
# alpha                    0.0378273
# delta                    0.1
# env_samples         940247
# eval_score           -4001.61
# eval_success             0
# kl_dist                  0.0486409
# num_samples           9600
# rollout_success          0
# running_score        -4698.32
# rwd_dense              -46.745
# rwd_sparse              -0.484118
# stoc_pol_max         -3643.36
# stoc_pol_mean        -4674.5
# stoc_pol_min         -5056.48
# stoc_pol_std           360.447
# success_percentage       0
# surr_improvement       nan
# time_VF                  7.26335
# time_npg                 0.612028
# time_sampling           35.9889
# time_vpg                 0.0376191
# ------------------  ----------------
# ......................................................................................
# ITERATION : 98
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDCF0>
# [ Sat May 17 18:57:13 2025 ]   98 -4712.51 -4037.63 -4537.26
# ------------------  ----------------
# VF_error_after           0.000545701
# VF_error_before          0.000724161
# alpha                    0.0393643
# delta                    0.1
# env_samples         949847
# eval_score           -4037.63
# eval_success             0
# kl_dist                  0.0448462
# num_samples           9600
# rollout_success          0
# running_score        -4699.74
# rwd_dense              -47.1251
# rwd_sparse              -0.497695
# stoc_pol_max         -3731.8
# stoc_pol_mean        -4712.51
# stoc_pol_min         -5056.63
# stoc_pol_std           336.752
# success_percentage       0
# surr_improvement       nan
# time_VF                  6.64636
# time_npg                 0.533984
# time_sampling           33.044
# time_vpg                 0.0270615
# ------------------  ----------------
# ......................................................................................
# ITERATION : 99
# Simulation couldn't be stepped as intended. Issuing a reset
# Simulation couldn't be stepped as intended. Issuing a reset
# Performing evaluation rollouts ........
# <generator object train_agent.<locals>.<genexpr> at 0x0000019289DCDC10>
# [ Sat May 17 18:57:55 2025 ]   99 -4671.17 -4024.01 -4537.26
# ------------------  ----------------
# VF_error_after           0.000537015
# VF_error_before          0.00073609
# alpha                    0.0360504
# delta                    0.1
# env_samples         959447
# eval_score           -4024.01
# eval_success             0
# kl_dist                  0.0434617
# num_samples           9600
# rollout_success          0
# running_score        -4696.88
# rwd_dense              -46.7117
# rwd_sparse              -0.455591
# stoc_pol_max         -3597.31
# stoc_pol_mean        -4671.17
# stoc_pol_min         -5058.29
# stoc_pol_std           351.271
# success_percentage       0
# surr_improvement       nan
# time_VF                  5.21272
# time_npg                 0.448218
# time_sampling           32.1479
# time_vpg                 0.026581
# ------------------  ----------------
# ......................................................................................
# ITERATION : 100

# %% [markdown]
# <h1> Logging hyperparameters

# %%
import logging

# Configure the logging system
logging.basicConfig(
    filename=r'C:\Users\Elyas\OneDrive - The University of Colorado Denver\Desktop\Research 2024\Research_papers/training_hyperparameters.log',  # Log file name
    level=logging.INFO,  # Set the logging level to INFO
    format='%(asctime)s - %(levelname)s - %(message)s',  # Log message format
)

# %%
# Policy Network Hyperparameters
policy_hyperparameters = {
    'policy_size': (256, 256),
    'seed': 123,
    'rl_step_size': 0.1,
    'learnrate': 0.0025,
    'entcoeff': 0.1,
    'batchsize': 32,
    'num_epoch': 10,
}

# Value Function Network Hyperparameters
vf_hyperparameters = {
    'vf_hidden_size': (256, 256),
    'seed': 123,
    'rl_step_size': 0.1,
    'learnrate': 0.000325,
    'entcoeff': 0.1,
    'batchsize': 32,
    'num_epoch': 10,
    'regcoef': 1e-3,
}

# Training Hyperparameters
training_hyperparameters = {
    'iterations': 1000,
    'gamma': 0.995,
    'gae_lambda': 0.97,
}

# Log Hyperparameters
def log_hyperparameters():
    logging.info("Policy Network Hyperparameters:")
    for key, value in policy_hyperparameters.items():
        logging.info(f"{key}: {value}")
    
    logging.info("\nValue Function Network Hyperparameters:")
    for key, value in vf_hyperparameters.items():
        logging.info(f"{key}: {value}")
    
    logging.info("\nTraining Hyperparameters:")
    for key, value in training_hyperparameters.items():
        logging.info(f"{key}: {value}")

# Call the function to log hyperparameters
log_hyperparameters()
